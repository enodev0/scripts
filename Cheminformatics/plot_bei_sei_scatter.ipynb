# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df <- read_csv("screenlib-bei-sei.csv", col_names=TRUE)
# Out:
# Parsed with column specification:
# cols(
#   Ligand = col_character(),
#   Isoform = col_integer(),
#   deltaG = col_double(),
#   MW = col_double(),
#   Ki = col_double(),
#   pKi = col_double(),
#   BEI = col_double(),
#   SEI = col_double()
# )

# %%
head(df)
# Out:
#   Ligand     Isoform deltaG MW      Ki    pKi   BEI    SEI
# 1 reduce-134 1       -7.2   280.369 5.238 5.281 18.836 6.124
# 2 reduce-449 1       -7.2   274.318 5.238 5.281 19.251 8.006
# 3 reduce-439 1       -7.2   273.291 5.238 5.281 19.324 6.091
# 4 reduce-419 1       -7.0   273.310 7.343 5.134 18.785 6.950
# 5 reduce-83  1       -7.0   272.322 7.343 5.134 18.853 8.347
# 6 reduce-287 1       -7.0   261.320 7.343 5.134 19.646 6.260

# %%
dfa <- filter(df, Isoform == 1)
dfb <- filter(df, Isoform == 2)

# %%
# ISOFORM-1
ggplot(dfa,aes(x=SEI, y=BEI)) + geom_point(alpha=0.3) +
coord_cartesian(xlim = c(0, 50), ylim = c(0,50)) +
geom_abline(intercept=0, slope=1) + theme_linedraw() + theme(text = element_text(size=30))
# Out:
# plot without title

# %%
filter(dfa, BEI > 15 & SEI > 16 & SEI < 25)
# Out:
#    Ligand     Isoform deltaG MW      Ki      pKi   BEI    SEI
# 1  reduce-227 1       -6.1   234.334  33.570 4.474 19.092 17.011
# 2  reduce-9   1       -6.0   206.281  39.747 4.401 21.335 16.734
# 3  reduce-172 1       -5.9   163.259  47.060 4.327 26.504 18.143
# 4  reduce-202 1       -5.9   191.313  47.060 4.327 22.617 18.143
# 5  reduce-400 1       -5.8   176.258  55.718 4.254 24.135 17.209
# 6  reduce-252 1       -5.7   229.317  65.969 4.181 18.232 16.062
# 7  reduce-468 1       -5.7   227.302  65.969 4.181 18.394 16.062
# 8  reduce-381 1       -5.7   243.344  65.969 4.181 17.181 16.062
# 9  reduce-4   1       -5.7   208.320  65.969 4.181 20.070 17.991
# 10 reduce-344 1       -5.7   243.344  65.969 4.181 17.181 16.062
# 11 reduce-224 1       -5.6   196.309  78.106 4.107 20.921 16.648
# 12 reduce-120 1       -5.5   260.299  92.476 4.034 15.498 16.540
# 13 reduce-303 1       -5.5   175.270  92.476 4.034 23.016 16.957
# 14 reduce-87  1       -5.5   201.307  92.476 4.034 20.039 16.957
# 15 reduce-171 1       -5.5   215.334  92.476 4.034 18.734 16.957
# 16 reduce-425 1       -5.4   191.293 109.489 3.961 20.706 16.608
# 17 reduce-162 1       -5.3   233.349 129.634 3.887 16.657 18.004
# 18 reduce-10  1       -5.2   206.324 153.484 3.814 18.485 18.853
# 19 reduce-164 1       -5.2   187.281 153.484 3.814 20.365 16.032
# 20 reduce-272 1       -5.1   193.285 181.722 3.741 19.355 17.327
# 21 reduce-196 1       -5.1   219.323 181.722 3.741 17.057 17.327
# 22 reduce-158 1       -5.1   219.323 181.722 3.741 17.057 17.327
# 23 reduce-310 1       -5.0   235.365 215.155 3.667 15.580 16.985
# 24 reduce-288 1       -5.0   221.339 215.155 3.667 16.567 16.985
# 25 reduce-369 1       -4.9   192.297 254.740 3.594 18.690 17.766
# 26 reduce-119 1       -4.9   225.302 254.740 3.594 15.952 16.647
# 27 reduce-239 1       -4.7   190.281 357.098 3.447 18.115 17.039

# %%
# ISOFORM-2
ggplot(dfb,aes(x=SEI, y=BEI)) + geom_point(alpha=0.2) +
coord_cartesian(xlim = c(0, 50), ylim = c(0,50)) +
geom_abline(intercept=0, slope=1) + theme_linedraw() + theme(text = element_text(size=30))
# Out:
# plot without title

# %%
filter(dfb, BEI > 16 & BEI < 22 & SEI > 17.5 & SEI < 22)
# Out:
#    Ligand     Isoform deltaG MW      Ki      pKi   BEI    SEI    highlight
# 1  reduce-381 2       -6.7   243.344  12.187 4.914 20.194 18.878 normal
# 2  reduce-344 2       -6.7   243.344  12.187 4.914 20.194 18.878 normal
# 3  reduce-299 2       -6.5   229.317  17.084 4.767 20.788 18.313 normal
# 4  reduce-252 2       -6.3   229.317  23.948 4.621 20.151 17.753 normal
# 5  reduce-468 2       -6.3   227.302  23.948 4.621 20.330 17.753 normal
# 6  reduce-120 2       -6.3   260.299  23.948 4.621 17.753 18.946 normal
# 7  reduce-162 2       -6.2   233.349  28.354 4.547 19.486 21.061 normal
# 8  reduce-171 2       -6.1   215.334  33.570 4.474 20.777 18.806 normal
# 9  reduce-196 2       -6.0   219.323  39.747 4.401 20.066 20.384 normal
# 10 reduce-10  2       -6.0   206.324  39.747 4.401 21.331 21.755 normal
# 11 reduce-4   2       -6.0   208.320  39.747 4.401 21.126 18.937 normal
# 12 reduce-87  2       -5.8   201.307  55.718 4.254 21.132 17.881 normal
# 13 reduce-310 2       -5.8   235.365  55.718 4.254 18.074 19.704 normal
# 14 reduce-236 2       -5.8   201.307  55.718 4.254 21.132 17.881 normal
# 15 reduce-217 2       -5.8   206.324  55.718 4.254 20.618 21.028 normal
# 16 reduce-158 2       -5.7   219.323  65.969 4.181 19.063 19.365 normal
# 17 reduce-369 2       -5.7   192.297  65.969 4.181 21.742 20.667 normal
# 18 reduce-288 2       -5.6   221.339  78.106 4.107 18.555 19.023 normal
# 19 reduce-119 2       -5.6   225.302  78.106 4.107 18.229 19.023 normal
# 20 reduce-231 2       -5.6   192.297  78.106 4.107 21.358 20.302 normal
# 21 reduce-272 2       -5.5   193.285  92.476 4.034 20.871 18.685 normal
# 22 reduce-1   2       -5.5   184.250  92.476 4.034 21.894 19.941 normal
# 23 reduce-415 2       -5.3   224.339 129.634 3.887 17.326 21.056 normal

# %%
head(dfa)
# Out:
#   Ligand     Isoform deltaG MW      Ki    pKi   BEI    SEI
# 1 reduce-134 1       -7.2   280.369 5.238 5.281 18.836 6.124
# 2 reduce-449 1       -7.2   274.318 5.238 5.281 19.251 8.006
# 3 reduce-439 1       -7.2   273.291 5.238 5.281 19.324 6.091
# 4 reduce-419 1       -7.0   273.310 7.343 5.134 18.785 6.950
# 5 reduce-83  1       -7.0   272.322 7.343 5.134 18.853 8.347
# 6 reduce-287 1       -7.0   261.320 7.343 5.134 19.646 6.260

# %%
# ISOFORM-1
ab1 <- data.frame(filter(dfa, Ligand %in% c("reduce-134", "reduce-439", "chembl-dbank-min-red_2", "triacsinC")))
ab1[1,1] <- "R134"
ab1[2,1] <- "R439"
ab1[3,1] <- "Triacsin C"
ab1[4,1] <- "CDB2"
ggplot(NULL,aes(x=SEI, y=BEI)) + geom_point(data=dfa,alpha=0.5, color="#f0c454") +
coord_cartesian(xlim = c(0, 50), ylim = c(0,50)) +
geom_point(data=ab1, aes(x=SEI,y=BEI, color=Ligand)) +
geom_abline(intercept=0, slope=1)+
theme_linedraw() +
theme(text = element_text(size=15))
# Out:
# plot without title

# %%
# ISOFORM-2
ab2 <- data.frame(filter(dfb, Ligand %in% c("reduce-134", "reduce-38", "D1Tric", "triacsinC")))
ab2[1,1] <- "R134"
ab2[2,1] <- "MCD1"
ab2[3,1] <- "R38"
ab2[4,1] <- "Triacsin C"
ggplot(NULL,aes(x=SEI, y=BEI)) + geom_point(data=dfb,alpha=0.5, color="#f0c454") +
coord_cartesian(xlim = c(0, 50), ylim = c(0,50)) +
geom_point(data=ab2, aes(x=SEI,y=BEI, color=Ligand)) +
geom_abline(intercept=0, slope=1)+
theme_linedraw() +
theme(text = element_text(size=15))
# Out:
# plot without title

# %%
# Isoform1
ab1 <- data.frame(filter(dfa, Ligand %in% c("reduce-134", "reduce-439", "chembl-dbank-min-red_2", "triacsinC")))
ab1[1,1] <- "R134"
ab1[2,1] <- "R439"
ab1[3,1] <- "Triacsin C"
ab1[4,1] <- "CDB2"
ggplot(NULL,aes(x=SEI, y=BEI)) + geom_point(data=dfa, alpha=0.3) + geom_point(data=ab1, color="red",size=2) +
coord_cartesian(xlim = c(0, 50), ylim = c(0,50)) +
geom_abline(intercept=0, slope=1) + theme_linedraw() + theme(text = element_text(size=30))
# Out:
# plot without title

# %%
# ISOFORM-2
ab2 <- data.frame(filter(dfb, Ligand %in% c("reduce-134", "reduce-38", "D1Tric", "triacsinC")))
ab2[1,1] <- "R134"
ab2[2,1] <- "MCD1"
ab2[3,1] <- "R38"
ab2[4,1] <- "Triacsin C"
ggplot(NULL,aes(x=SEI, y=BEI)) + geom_point(data=dfb,alpha=0.2) + geom_point(data=ab2, color="red",size=2) +
coord_cartesian(xlim = c(0, 50), ylim = c(0,50)) +
geom_abline(intercept=0, slope=1) + theme_linedraw() + theme(text = element_text(size=30))
# Out:
# plot without title

# %%
ab2
# Out:
#   Ligand     Isoform deltaG MW      Ki     pKi   BEI    SEI   highlight
# 1 R134       2       -8.2   280.369  0.968 6.014 21.450 6.974 highlight
# 2 MCD1       2       -7.8   298.379  1.901 5.721 19.174 9.274 normal
# 3 R38        2       -7.7   278.373  2.251 5.648 20.289 7.736 normal
# 4 Triacsin C 2       -6.1   207.272 33.570 4.474 21.585 8.313 normal

# %% [markdown]
# ## Consider finding out the molecules within vicinity of the BEI-SEI diagonal plane using the BEI/SEI ratio, a value of 1 would indicate that the ligand is on the diagonal. If (BEI/SEI) > 1, then ligand is above the plane a vice-versa. Propose the molecules near/on the diagonal as potential optimization candidates too.

# %%
dfa_ratio <- (dfa$BEI/dfa$SEI)
dfb_ratio <- (dfb$BEI/dfb$SEI)

# %%
head(dfa_ratio)
# Out:
# [1] 3.075767 2.404572 3.172550 2.702878 2.258656 3.138339

# %%
efficiency_ratio <- (df$BEI/df$SEI)

# %%
head(efficiency_ratio)
# Out:
# [1] 3.075767 2.404572 3.172550 2.702878 2.258656 3.138339

# %%
df <- cbind(df, efficiency_ratio)

# %%
colnames(df)[9] <- "BSRatio"

# %%
head(df)
# Out:
#   Ligand     Isoform deltaG MW      Ki    pKi   BEI    SEI   BSRatio
# 1 reduce-134 1       -7.2   280.369 5.238 5.281 18.836 6.124 3.075767
# 2 reduce-449 1       -7.2   274.318 5.238 5.281 19.251 8.006 2.404572
# 3 reduce-439 1       -7.2   273.291 5.238 5.281 19.324 6.091 3.172550
# 4 reduce-419 1       -7.0   273.310 7.343 5.134 18.785 6.950 2.702878
# 5 reduce-83  1       -7.0   272.322 7.343 5.134 18.853 8.347 2.258656
# 6 reduce-287 1       -7.0   261.320 7.343 5.134 19.646 6.260 3.138339

# %%
write_csv(df, path = "screenlib-bei-sei-withRatio.csv", col_names=TRUE)

# %%
filter(df, BSRatio <= 1.1 & BSRatio >= 0.9)
# Out:
#    Ligand     Isoform deltaG MW      Ki      pKi   BEI    SEI    BSRatio
# 1  reduce-1   1       -6.3   184.250  23.948 4.621 25.080 22.842 1.0979774
# 2  reduce-27  1       -5.8   176.255  55.718 4.254 24.135 24.921 0.9684603
# 3  reduce-217 1       -5.8   206.324  55.718 4.254 20.618 21.028 0.9805022
# 4  reduce-231 1       -5.7   192.297  65.969 4.181 21.742 20.667 1.0520153
# 5  reduce-381 1       -5.7   243.344  65.969 4.181 17.181 16.062 1.0696675
# 6  reduce-344 1       -5.7   243.344  65.969 4.181 17.181 16.062 1.0696675
# 7  reduce-120 1       -5.5   260.299  92.476 4.034 15.498 16.540 0.9370012
# 8  reduce-162 1       -5.3   233.349 129.634 3.887 16.657 18.004 0.9251833
# 9  reduce-10  1       -5.2   206.324 153.484 3.814 18.485 18.853 0.9804806
# 10 reduce-196 1       -5.1   219.323 181.722 3.741 17.057 17.327 0.9844174
# 11 reduce-158 1       -5.1   219.323 181.722 3.741 17.057 17.327 0.9844174
# 12 reduce-310 1       -5.0   235.365 215.155 3.667 15.580 16.985 0.9172800
# 13 reduce-288 1       -5.0   221.339 215.155 3.667 16.567 16.985 0.9753901
# 14 reduce-369 1       -4.9   192.297 254.740 3.594 18.690 17.766 1.0520095
# 15 reduce-119 1       -4.9   225.302 254.740 3.594 15.952 16.647 0.9582507
# 16 reduce-239 1       -4.7   190.281 357.098 3.447 18.115 17.039 1.0631492
# 17 reduce-381 2       -6.7   243.344  12.187 4.914 20.194 18.878 1.0697108
# 18 reduce-344 2       -6.7   243.344  12.187 4.914 20.194 18.878 1.0697108
# 19 reduce-120 2       -6.3   260.299  23.948 4.621 17.753 18.946 0.9370316
# 20 reduce-162 2       -6.2   233.349  28.354 4.547 19.486 21.061 0.9252172
# 21 reduce-196 2       -6.0   219.323  39.747 4.401 20.066 20.384 0.9843995
# 22 reduce-10  2       -6.0   206.324  39.747 4.401 21.331 21.755 0.9805102
# 23 reduce-310 2       -5.8   235.365  55.718 4.254 18.074 19.704 0.9172757
# 24 reduce-239 2       -5.8   190.281  55.718 4.254 22.356 21.028 1.0631539
# 25 reduce-217 2       -5.8   206.324  55.718 4.254 20.618 21.028 0.9805022
# 26 reduce-158 2       -5.7   219.323  65.969 4.181 19.063 19.365 0.9844049
# 27 reduce-369 2       -5.7   192.297  65.969 4.181 21.742 20.667 1.0520153
# 28 reduce-288 2       -5.6   221.339  78.106 4.107 18.555 19.023 0.9753982
# 29 reduce-119 2       -5.6   225.302  78.106 4.107 18.229 19.023 0.9582611
# 30 reduce-231 2       -5.6   192.297  78.106 4.107 21.358 20.302 1.0520146
# 31 reduce-1   2       -5.5   184.250  92.476 4.034 21.894 19.941 1.0979389
# 32 reduce-27  2       -5.4   176.255 109.489 3.961 22.473 23.204 0.9684968

# %%
a <- filter(df, Isoform == 1)

# %%
head(a)
# Out:
#   Ligand     Isoform deltaG MW      Ki    pKi   BEI    SEI
# 1 reduce-134 1       -7.2   280.369 5.238 5.281 18.836 6.124
# 2 reduce-449 1       -7.2   274.318 5.238 5.281 19.251 8.006
# 3 reduce-439 1       -7.2   273.291 5.238 5.281 19.324 6.091
# 4 reduce-419 1       -7.0   273.310 7.343 5.134 18.785 6.950
# 5 reduce-83  1       -7.0   272.322 7.343 5.134 18.853 8.347
# 6 reduce-287 1       -7.0   261.320 7.343 5.134 19.646 6.260

# %%
filter(a, grepl("chembl", Ligand))
# Out:
#    Ligand                  Isoform deltaG MW      Ki      pKi   BEI    SEI
# 1  chembl-dbank-min-red_19 1       -5.3   230.302 129.634 3.887 16.878 10.421
# 2  chembl-dbank-min-red_7  1       -6.1   253.339  33.570 4.474 17.660  6.530
# 3  chembl-dbank-min-red_11 1       -5.4   221.339 109.489 3.961 17.896 13.612
# 4  chembl-dbank-min-red_18 1       -5.3   230.302 129.634 3.887 16.878 10.421
# 5  chembl-dbank-min-red_0  1       -5.2   251.388 153.484 3.814 15.172  7.011
# 6  chembl-dbank-min-red_10 1       -6.2   231.333  28.354 4.547 19.656 15.625
# 7  chembl-dbank-min-red_3  1       -5.4   234.357 109.489 3.961 16.902  9.349
# 8  chembl-dbank-min-red_4  1       -5.6   251.388  78.106 4.107 16.337  7.550
# 9  chembl-dbank-min-red_9  1       -6.2   217.307  28.354 4.547 20.924 15.625
# 10 chembl-dbank-min-red_14 1       -5.6   237.361  78.106 4.107 17.303  6.049
# 11 chembl-dbank-min-red_2  1       -7.4   234.294   3.737 5.427 23.163  8.797
# 12 chembl-dbank-min-red_5  1       -6.3   245.317  23.948 4.621 18.837 10.009
# 13 chembl-dbank-min-red_8  1       -5.4   221.339 109.489 3.961 17.896 13.612
# 14 chembl-dbank-min-red_12 1       -6.1   262.344  33.570 4.474 17.054  9.615
# 15 chembl-dbank-min-red_15 1       -5.4   266.313 109.489 3.961 14.873  5.947
# 16 chembl-dbank-min-red_1  1       -6.3   237.361  23.948 4.621 19.468  6.806
# 17 chembl-dbank-min-red_17 1       -6.3   234.357  23.948 4.621 19.718 15.533
# 18 chembl-dbank-min-red_16 1       -5.4   241.714 109.489 3.961 16.387  9.472
# 19 chembl-dbank-min-red_6  1       -5.9   250.363  47.060 4.327 17.283  5.316
# 20 chembl-dbank-min-red_13 1       -6.0   262.323  39.747 4.401 16.777 10.615
